# %%
#Question no:1
num1 = 25
num2 = 3.5

print("integer value:", num1)
print("float value:", num2)

# %%
#Question no: 2
name = "Muhammad Shahban"
is_student = True

print("Name :", name)
print("Is he student at IUB? :", is_student)

# %%
#Question no: 3
value1 = int(input("enter 1st number: "))
value2 = int(input("enter 2nd number: "))

print("Addition of values :", value1 + value2)
print("Subtraction of values :", value1 - value2)
print("Multiplication of values :", value1 * value2)
print("Division of values :", value1 / value2)

# %%
#Question no: 4
num = int(input("enter a number: "))

print("floor Division by 5:", num // 5)
print("Remainder when divided by 5:", num % 5)

# %%
#Question no: 5

# this is the expression
  5 + 3

# this the statement
print("Hello World")

# %%
#Question no: 6
num1 = int(input("enter the number: "))

result = num1 * 10
print("Result is given: ", result)

# %%
#Question no:7
first_name = "Muhammad"
last_name = "Shahban"

full_name = first_name + " " + last_name
print("Full Name is: ", full_name)

# %%
#Question no: 8
word = input("enter any word: ")

print(word * 3)

# %%
#Question no: 9
text = "Python Programming"

print("first 6 letter are: ", text[:6])
print("Remaining remaining: ", text[6:])

# %%
#Question no: 10
text = "hello world"

print("Uppercase:", text.upper())
print("Title Case:", text.title())
print("Length:", len(text))
